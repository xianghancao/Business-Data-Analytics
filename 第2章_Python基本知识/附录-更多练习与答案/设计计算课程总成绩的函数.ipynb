# %% [markdown]
# # 练习：设计计算课程总成绩的函数
#
# ![计算课程总成绩](图片/计算课程总成绩.png)
#
# 相信很多老师在授课的第一节课都会告诉学生，本学期的考核和成绩评定方式。现在学校要求我们编写一个函数cal_score，让学生输入他本学期的16周的出勤次数、平时作业成绩、期中测验分数和期末卷面成绩来计算出他的总成绩。
#
# ```python
# #'name':'zhangxiaoxian' 姓名
# #'attendance_numbers' 出勤数
# #'homework_score' 平时作业分数
# #'mid-term_exam_score' 期中考试分数
# #'final_term_score' 期末考试分数
#
# def cal_score():
#   # 1. 打印学生的平时成绩
#   # 2. 打印课程总成绩
# 	return
#
# ```
#
# ## **答案**
#
# 我们定义以下变量：
#
# <style>
# table th:first-of-type {
#     width: 10%;
# }
# table th:nth-of-type(2) {
#     width: 20%;
# }
# </style>
#
# | 中文名词     | 英文变量名称        |
# | ------------ | ------------------- |
# | 课程总成绩   | total_score         |
# | 平时成绩     | regular_score       |
# | 期末成绩     | final_term_score    |
# | 出勤次数     | attendance_numbers  |
# | 出勤率       | attendance_rate     |
# | 平时作业成绩 | homework_score      |
# | 期中考试成绩 | mid_term_exam_score |
#
# 接下来，我们分步骤来完成程序，从最核心的步骤开始：
#
# 第一步 计算出勤率
#
# ```python
# student = {'name':'zhangxiaoxian', #姓名
#               'attendance_numbers': 14, #出勤数
#              'homework_score': 75,  #平时作业分数
#              'mid_term_exam_score': 80, #期中考试分数
#              'final_term_score': 85}  #期末考试分数
# attendance_rate = student['attendance_numbers']/16
# ```
#
# 第二步 计算平时成绩
#
# ```python
# homework_score = student['homework_score']
# mid_term_exam_score = student['mid_term_exam_score']
# regular_score = attendance_rate * 100 * 0.25 + homework_score * 0.25 + mid_term_exam_score * 0.50
# ```
#
# 第二步 计算总成绩
#
# ```python
# final_term_score = student['final_term_score']
# total_score = regular_score * 0.4 + final_term_score * 0.6
# ```
#
# 第三步 打印
#
# ```python
# print('Hi, your total score is ', total_score)
# Hi, your total score is  75.9
# ```
#
# 第四步 判断
#
# ```python
# if attendance_rate < 1/3: # 如果出勤率低于1/3, 重修；大于1/3, 打印总成绩
#     print('Your attendance rate:', attendance_rate, 'which below 1/3,')
#     print('Your have failed this course, please retake!')
# else:
#     print('Hi, your total score is ', total_score)
#
# ```
#
# 第五步 合并
#
# ```python
# attendance_rate = student['attendance_numbers']/16
# if attendance_rate < 1/3:
#     print('Your attendance rate:', attendance_rate, 'which below 1/3,')
#     print('Your have failed this course, please retake!')
# else:
#     homework_score = student['homework_score']
#     mid_term_exam_score = student['mid_term_exam_score']
#     regular_score = attendance_rate * 100 * 0.25 + homework_score * 0.25 + mid_term_exam_score * 0.50
#     final_term_score = student['final_term_score']
#     total_score = regular_score * 0.4 + final_term_score * 0.6
#     print('Hi, your total score is ', total_score)
# ```
#
# 第六步 构造函数
#
# 使用def语句、位置参数和return语句构造函数：
#
# ```python
# def cal_score(student):
#     # 计算逻辑
#     return total_score
# ```
#
# 将上一步语句放入函数中：
#
# ```python
# def cal_score(student):
#     attendance_rate = student['attendance_numbers']/16
#     if attendance_rate < 1/3:
#         print('Your attendance rate:', attendance_rate, 'which below 1/3,')
#         print('Your have failed this course, please retake!')
#     else:
#         homework_score = student['homework_score']
#         mid_term_exam_score = student['mid_term_exam_score']
#         regular_score = attendance_rate * 100 * 0.25 + homework_score * 0.25 + mid_term_exam_score * 0.50
#         final_term_score = student['final_term_score']
#         total_score = regular_score * 0.4 + final_term_score * 0.6
#         print('Hi, your total score is ', total_score)
#     return total_score
# ```
#
# 最后，测试：
#
# ```python
# cal_score(student_01)
# cal_score(student_02)
# total_score = cal_score(student_03)
# print(total_score)
# ```
#
# cal_score(student_02)的运行结果是：student_02出勤率不够1/3，程序要告诉他重修。
